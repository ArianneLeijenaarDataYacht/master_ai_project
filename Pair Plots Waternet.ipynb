# %% [markdown]
# WATERNET PAIRPLOTS

# %%
import pandas as pd
import numpy as np
import datetime as dt
waternet = pd.read_pickle("5018 2011-2020.pkl")

# %%
print(waternet[:5])
# Out:
#                      5018 putniveau gemaal  Overstort 623 (-1,10)  \
# Tijd
# 2011-01-01 00:00:00                  -2.10                    NaN
# 2011-01-01 00:05:00                  -2.11                    NaN
# 2011-01-01 00:10:00                  -2.11                    NaN
# 2011-01-01 00:15:00                  -2.11                    NaN
# 2011-01-01 00:20:00                  -2.11                    NaN
#
#                      Overstort 624 (-1,00)  BBB riool  BBB bassin begin  \
# Tijd
# 2011-01-01 00:00:00                    NaN     -2.479            -4.244
# 2011-01-01 00:05:00                    NaN     -2.480            -4.244
# 2011-01-01 00:10:00                    NaN     -2.483            -4.244
# 2011-01-01 00:15:00                    NaN     -2.485            -4.244
# 2011-01-01 00:20:00                    NaN     -2.487            -4.244
#
#                      BBB bassin eind  BBB-buffer  \
# Tijd
# 2011-01-01 00:00:00            -3.29      -2.530
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(waternet)
